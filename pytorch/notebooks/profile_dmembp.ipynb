# %%
# %reload_ext autoreload
# %autoreload 2
import sys
import os
from pathlib import Path

from torch.utils.data import DataLoader
from torch.profiler import profile, ProfilerActivity, record_function
from qecdec import RotatedSurfaceCode_Memory

d = 7
p = 0.01
rounds = d
batch_size = 256

decoder_kwargs = dict(num_iters=5)
loss_fn_kwargs = dict(beta=0.8)

device = "cpu"

pytorch_dir = Path(os.getcwd()).parent
sys.path.append(str(pytorch_dir))

output_dir = pytorch_dir / "runs"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
expmt = RotatedSurfaceCode_Memory(
    d=d,
    rounds=rounds,
    basis='Z',
    data_qubit_error_rate=p,
    meas_error_rate=p,
)
print("Number of error mechanisms:", expmt.num_error_mechanisms)
print("Number of detectors:", expmt.num_detectors)
print("Number of observables:", expmt.num_observables)
# Out:
# Number of error mechanisms: 512
# Number of detectors: 192
# Number of observables: 1

# %%
# Set up dataloaders.
from src.dataset import DecodingDataset

dataset_dir = pytorch_dir / "datasets" / "rotated_surface_code_memory_Z" / f"d={d}_rounds={rounds}_p={p}"
train_dataset = DecodingDataset.load_from_file(dataset_dir / "train_dataset.pt")
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# Set up decoder model and loss function.
from src.models import Learned_DMemBPDecoder
from src.training import IterativeDecodingLoss

decoder = Learned_DMemBPDecoder(expmt.chkmat, expmt.prior, **decoder_kwargs)
loss_fn = IterativeDecodingLoss(expmt.chkmat, expmt.obsmat, **loss_fn_kwargs)

# %%
decoder = decoder.to(device)
decoder.train()
for syndromes, observables in train_dataloader:
    syndromes = syndromes.to(device)
    observables = observables.to(device)

    with profile(
        activities=[ProfilerActivity.CPU],
        with_stack=True,
    ) as prof:
        with record_function("forward pass"):
            llrs = decoder(syndromes)
            loss = loss_fn(llrs, syndromes, observables)
    print("=" * 100)
    prof.export_chrome_trace(str(output_dir / "forward_trace.json"))
    print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))

    with profile(
        activities=[ProfilerActivity.CPU],
        with_stack=True,
    ) as prof:
        with record_function("backward pass"):
            loss.backward()
    print("=" * 100)
    prof.export_chrome_trace(str(output_dir / "backward_trace.json"))
    print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))

    break
# Out:
# ====================================================================================================
# ------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                       Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                               forward pass        25.34%      76.247ms       100.00%     300.838ms     300.838ms             1
#                              aten::softmax         0.18%     543.065us        16.62%      50.007ms      52.090us           960
#                             aten::_softmax        16.44%      49.464ms        16.44%      49.464ms      51.525us           960
#                                aten::stack         2.72%       8.186ms        10.38%      31.241ms       8.396us          3721
#                               aten::repeat         1.79%       5.399ms         8.99%      27.053ms      14.090us          1920
#                                aten::copy_         5.92%      17.795ms         5.92%      17.795ms       2.221us          8012
#                                  aten::cat         4.41%      13.264ms         5.61%      16.870ms       4.534us          3721
#                          aten::masked_fill         1.04%       3.143ms         5.60%      16.832ms       8.767us          1920
#                                  aten::sum         4.89%      14.705ms         5.58%      16.795ms       4.767us          3523
#                                  aten::mul         4.82%      14.501ms         5.55%      16.700ms       2.054us          8132
# ------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 300.838ms
#
# ====================================================================================================
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                           backward pass        30.66%     100.561ms       100.00%     327.990ms     327.990ms             1
#       autograd::engine::evaluate_function: MulBackward0         5.27%      17.287ms        15.72%      51.566ms       7.819us          6595
#      autograd::engine::evaluate_function: ProdBackward1         1.03%       3.394ms        11.19%      36.710ms      47.737us           769
#                                           ProdBackward1         1.10%       3.602ms        10.16%      33.316ms      43.324us           769
#                                               aten::mul         8.25%      27.075ms         8.73%      28.648ms       2.622us         10924
#                                            MulBackward0         1.35%       4.442ms         8.55%      28.051ms       4.253us          6595
#                                               aten::sum         6.11%      20.030ms         7.81%      25.628ms       3.777us          6786
# autograd::engine::evaluate_function: SoftmaxBackward...         0.60%       1.970ms         6.72%      22.055ms      38.290us           576
#                                        SoftmaxBackward0         0.21%     703.025us         6.12%      20.085ms      34.871us           576
#                            aten::_softmax_backward_data         5.91%      19.382ms         5.91%      19.382ms      33.650us           576
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 327.990ms
